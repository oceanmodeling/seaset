# %% [markdown]
# import pandas as pd
# import numpy as np
# import requests

# %%
from pydap.client import open_url

# %%
from dateutil.parser import parse

# %%
import datetime

# %%
import bisect

# %%
from thredds_crawler.crawl import Crawl

# %%
#import seaborn

# %%
from selenium import webdriver

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
# %matplotlib widget

# %% [markdown]
# # WebCritech catalog

# %%
critech = pd.read_csv('critech.csv')

# %%
critech.head()
# Out:
#    index  ID                       Name   Group Latency  Status  Details
# 0      1  62               Faial Island  AZO TD      0m     NaN  Details
# 1      2  64                   Terceira  AZO TD      0m     NaN  Details
# 2      4  56        Hanasaki, Japan HAN     BOM      0m     NaN  Details
# 3      5  59  Port Vila, Efate, Vanuatu     BOM      0m     NaN  Details
# 4      6  14      Suva, Viti Levu, Fiji     BOM      0m     NaN  Details

# %%
critech[critech['Name'].str.contains('Quarry')]
# Out:
#      index    ID                            Name      Group Latency  Status  \
# 618    634  2493  Hong Kong - China - Quarry Bay  TD UNESCO     15m     NaN
#
#      Details
# 618  Details

# %%
critech[critech.Group == 'TD UNESCO']['Name'].apply(lambda x : pd.Series(x.split('-')))
# Out:
#                                0                          1    2    3
# 395                  Antarctica                      Syowa   NaN  NaN
# 396                  Antarctica                  Vernadsky   NaN  NaN
# 397  Antigua, Barbuda & Redonda                     Barbuda  NaN  NaN
# 398                   Argentina              Mar del Plata   NaN  NaN
# 399                   Argentina             Puerto Deseado   NaN  NaN
# 400                   Argentina              Puerto Deseado  NaN  NaN
# 401                   Argentina              Puerto Madryn   NaN  NaN
# 402                   Argentina                     Ushuaia  NaN  NaN
# 403                   Australia                  Broome_AU   NaN  NaN
# 404                   Australia         Burnie_Tasmania_AU   NaN  NaN
# 405                   Australia           Cape Cuvier Wharf  NaN  NaN
# 406                   Australia           Cape_Ferguson_AU   NaN  NaN
# ...

# %% [markdown]
# ### get the data

# %%
from pyPoseidon.utils.obs import *

# %%
lat,lon = ioc[ioc['Station Name'].str.contains('Quarry')][['Latitude','Longitude']]

# %%
tg = obs()

# %%
tg.sdate = datetime.datetime(2016,8,20,0)
tg.edate = datetime.datetime(2016,9,1,0)
tg.point = critech[critech['Name'].str.contains('Quarry')]['ID'].values[0]

# %%
tg.getmes()

# %%
tg.data.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
